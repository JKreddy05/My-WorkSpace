# %% [markdown]
# <a href="https://colab.research.google.com/github/JKreddy05/My-WorkSpace/blob/main/simpsumr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install transformers

# %%
from transformers import pipeline, BartForConditionalGeneration, BartTokenizer

# %%
model_name = 'facebook/bart-large-cnn'
model = BartForConditionalGeneration.from_pretrained(model_name)
tokenizer = BartTokenizer.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
summarizer = pipeline("summarization", model=model_name)

# %%
print(len(sum.split()))
# Out:
# 519

# %%
token=tokenizer.tokenize(sum)
print(len(token))
if len(token)>1024:
  print("Length exceeds maximum length")
else:
  print("Length is within the maximum length")
# Out:
# 748
# Length is within the maximum length

# %%
print("Average wpm : 100")
n=int(input("Enter the number of minutes you wish to read : "))
maxw=int((100*n)+50)
minw=int(100*n)
print(maxw,minw)
min=int(minw*1.5)
max=int(maxw*1.5)
print(min,max)
# Out:
# Average wpm : 100
# Enter the number of minutes you wish to read : 5
# 550 500
# 750 825

# %%
summary = summarizer(text, max_length=max, min_length=min, do_sample=False, num_beams=3, length_penalty=2.0)
sum=str(summary[0]['summary_text'])
# Print the generated summary
print("Generated Summary:")
print(sum)
# Out:
# Your max_length is set to 825, but your input_length is only 815. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=407)
# Generated Summary:
# ...

# %%
text = """
Cats, scientifically known as Felis catus, are small, carnivorous mammals that are often kept as pets. They are known for their agility, playful behavior, and companionship they provide to humans. This essay explores various aspects of cats, including their history, behavior, physiology, and the role they play in human society.

History and Domestication

Cats have been associated with humans for thousands of years. Their domestication is believed to have started around 9,000 years ago in the Near East. Early human settlements attracted rodents, which in turn attracted wild cats. These cats helped control the rodent population, leading to a mutually beneficial relationship. Over time, humans began to appreciate cats not just for their hunting skills but also for their companionship, leading to the domestication of the species.

Ancient Egyptians revered cats and even worshipped them, associating them with the goddess Bastet. Cats were also valued in other ancient cultures, including those of Rome and China. Throughout history, cats have been both venerated and vilified. During the Middle Ages in Europe, cats were often associated with witchcraft and superstition, leading to widespread persecution. However, their role in controlling pests during the plague periods helped rehabilitate their image.

Physical Characteristics

Cats are known for their sleek, muscular bodies, sharp claws, and retractable claws. They possess keen senses, particularly sight and hearing, which make them excellent hunters. Their eyes are adapted for low-light conditions, allowing them to see well at night. A cat's whiskers, or vibrissae, are highly sensitive and help them navigate their environment.

Cats come in a variety of breeds, each with unique characteristics. Some of the most popular breeds include the Persian, Siamese, Maine Coon, and Bengal. Coat patterns and colors vary widely, from solid colors to stripes, spots, and other patterns. The texture of a cat's fur can also range from short and sleek to long and fluffy.

Behavior and Communication

Cats are known for their independence, but they can also form strong bonds with their human caregivers. They communicate using a combination of vocalizations, body language, and scent markings. Common vocalizations include meowing, purring, hissing, and growling. Each sound can convey different messages, from a greeting or request for food to a warning of potential danger.

Body language is also crucial in feline communication. A cat's posture, the position of its ears, tail, and eyes, all convey different emotions and intentions. For example, a cat with an arched back and puffed-up fur is likely feeling threatened, while a cat with a relaxed, upright tail is feeling friendly and confident.

Cats are also territorial animals. They mark their territory using scent glands located on their face, paws, and tail. Scratching is another way cats mark their territory, as it leaves both a visual mark and a scent.

Health and Lifespan

Cats are generally healthy animals, but they are prone to certain diseases and conditions. Common health issues include dental disease, obesity, and infections. Regular veterinary care, a balanced diet, and proper exercise are essential for maintaining a cat's health.

Vaccinations are crucial for preventing diseases such as rabies, feline leukemia, and feline distemper. Spaying and neutering are also important for preventing overpopulation and reducing the risk of certain health problems.

The average lifespan of a domestic cat is around 12 to 15 years, though some cats can live into their twenties. Factors such as diet, genetics, and living conditions can all influence a cat's lifespan.

Conclusion

Cats are remarkable creatures that have adapted to living alongside humans while retaining their wild instincts. Their unique blend of independence and affection makes them beloved pets worldwide. Understanding their history, behavior, and needs is essential for providing them with the care
"""
